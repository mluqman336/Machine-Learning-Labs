# %%
import pandas as pd
import numpy as np
#from dataprep.datasets import load_dataset   # Used to import / load dataset
#from dataprep.eda import create_report   # Used to load Report formate

# %%
df=pd.read_csv(r'C:\Users\Muhammad Luqman\Desktop\OPEN_ENDED_LAB_21JZELE0444_LUQMAN\5_features_extracted.csv', index_col=['Datetime'], parse_dates=['Datetime'])
df.head()
# Out:
#                       aep  year_day  holiday  weekend  winter  spring  summer  \
# Datetime
# 2024-01-01 00:00:00  0.22         1        0        0       1       0       0
# 2024-01-01 01:00:00  0.22         1        0        0       1       0       0
# 2024-01-01 02:00:00  0.22         1        0        0       1       0       0
# 2024-01-01 03:00:00  0.22         1        0        0       1       0       0
# 2024-01-01 04:00:00  0.22         1        0        0       1       0       0
#
#                      fall  hour  month  day_of_week
# Datetime
# 2024-01-01 00:00:00     0     0      1            0
# 2024-01-01 01:00:00     0     1      1            0
# 2024-01-01 02:00:00     0     2      1            0
# 2024-01-01 03:00:00     0     3      1            0
# 2024-01-01 04:00:00     0     4      1            0

# %%
print('pearson\n\n',df.corrwith(df["aep"],method="pearson"))
# Out:
# pearson
#
#  aep            1.000000e+00
# year_day      -1.501354e-16
# holiday                 NaN
# weekend       -9.799972e-03
# winter         8.073803e-01
# spring        -3.979528e-01
# summer        -4.113290e-01
# fall           7.834307e-03
# hour           0.000000e+00
# month         -1.404552e-03
# day_of_week   -2.891058e-03
# dtype: float64

# %%
print('kendall\n\n',df.corrwith(df["aep"],method="kendall"))
# Out:
# kendall
#
#  aep            1.000000
# year_day       0.000000
# holiday             NaN
# weekend       -0.009800
# winter         0.807380
# spring        -0.397953
# summer        -0.411329
# fall           0.007834
# hour           0.000000
# month          0.000000
# day_of_week   -0.002528
# dtype: float64

# %%
print('spearman\n\n',df.corrwith(df["aep"],method="spearman"))
# Out:
# spearman
#
#  aep            1.000000
# year_day       0.000000
# holiday             NaN
# weekend       -0.009800
# winter         0.807380
# spring        -0.397953
# summer        -0.411329
# fall           0.007834
# hour           0.000000
# month          0.000000
# day_of_week   -0.002896
# dtype: float64
# C:\Users\Muhammad Luqman\anaconda3\envs\luqmanlabs\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())

# %%
df.isnull().sum()
# Out:
# aep            0
# year_day       0
# holiday        0
# weekend        0
# winter         0
# spring         0
# summer         0
# fall           0
# hour           0
# month          0
# day_of_week    0
# dtype: int64
